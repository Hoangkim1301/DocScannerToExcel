# %%
#translate handwritten Vietnamese text to text
import pytesseract
from PIL import Image

# Path to the uploaded image (containing handwritten Vietnamese text)
image_path = r"C:\\Users\\hoang\\Desktop\\DocScannerToExcel\\documents\\Screenshot_CC_3603.png"

# Use pytesseract to extract text from the image
extracted_text = pytesseract.image_to_string(Image.open(image_path), lang="vie")

# Print the extracted text
print("Extracted text from the image:")
print(extracted_text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\hoang\Desktop\DocScannerToExcel\env\Lib\site-packages\pytesseract\pytesseract.py:255, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254 try:
# --> 255     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256 except OSError as e:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
# ...

# %%
import cv2
import numpy as np

def clean_edge(image_path, output_path):
    # Load the image (replace 'UploadedImage8.jpg' with your image file)
    original_image = cv2.imread(image_path)

    # Convert to grayscale
    image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

    #Save the grayscale image
    #cv2.imwrite("grayscale_image.jpg", image)
    
    # Thresholding the image
    _, thresh = cv2.threshold(image, 150, 255, cv2.THRESH_BINARY_INV)
    
    cv2.imwrite("binary_image.jpg", thresh)

    # Using kernels to detect horizontal and vertical lines
    size = 40
    horizontal_kernel = np.ones((1, size), np.uint8)
    vertical_kernel = np.ones((size, 1), np.uint8)

    # Applying morphology transformations to detect lines separately
    horizontal_lines = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, horizontal_kernel)
    vertical_lines = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, vertical_kernel)

    # Subtract detected lines from the original thresholded image
    cleaned_image = thresh - horizontal_lines - vertical_lines
    #cleaned_image = thresh - vertical_lines

    # Inverting the cleaned image
    final_image = cv2.bitwise_not(cleaned_image)
    
    # Save the cleaned image
    cv2.imwrite(output_path, final_image)

    print(f"Cleaned image saved as {output_path}")
   

clean_edge(r"..\documents\ScanTest.jpg", "cleaned_image.jpg")
# Out:
# Cleaned image saved as cleaned_image.jpg

# %%
from PIL import Image
import cv2
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Users\hoang\AppData\Local\Programs\Tesseract-OCR\tesseract.exe'
# Path to the scanned image (replace 'scanned_image.jpg' with your image file)

#ScanTest
#CC_3603
image_path = r"..\documents\column5.jpg"

# Extract text using pytesseract
extracted_text = pytesseract.image_to_string(Image.open(image_path), lang="vie+eng")
print(extracted_text)   
# Save the extracted text to a text file (optional)
#with open("extracted_text.txt", "w", encoding="utf-8") as txt_file:
#    txt_file.write(extracted_text)

print("Text extracted successfully and saved to extracted_text.txt")
# Out:
# Quy đổi
#
# Text extracted successfully and saved to extracted_text.txt

# %%
from PIL import Image

# Load the scanned document image (replace 'scanned_document.jpg' with your image file)
image_path = r"..\documents\Cut.jpg"
image = Image.open(image_path)

# Define the coordinates for each column (adjust as needed)
column1 = (119, 0, 2362, 127)  # Leftmost column
#column2 = (320, 12, 500, image.height)
#column3 = (1290, 0, 1700, image.height)
#column4 = (1680, 12, 2100, image.height-20)
#column5 = (2200, 0, image.width-10, image.height)  # Rightmost column

# Crop each column
column1_image = image.crop(column1)
#column2_image = image.crop(column2)
#column3_image = image.crop(column3)
#column4_image = image.crop(column4)
#column5_image = image.crop(column5)

# Save each column as a separate image
column1_image.save(r"..\documents\column1.jpg")
#column2_image.save(r"..\documents\column2.jpg")
#column3_image.save(r"..\documents\column3.jpg")
#column4_image.save(r"..\documents\column4.jpg")
#column5_image.save(r"..\documents\column5.jpg")

print("Scanned document columns saved as column1.jpg, column2.jpg, column3.jpg, column4.jpg, and column5.jpg")
# Out:
# Scanned document columns saved as column1.jpg, column2.jpg, column3.jpg, column4.jpg, and column5.jpg

# %%
import cv2
import numpy as np
from PIL import Image

def detect_column_boundaries(image_path, num_columns):
    # Load the image
    image = Image.open(image_path)

    # Convert the image to grayscale
    gray_image = image.convert("L")

    # Convert to numpy array for OpenCV processing
    np_image = np.array(gray_image)

    # Apply Canny edge detection
    edges = cv2.Canny(np_image, 50, 150)

    # Find contours (potential column boundaries)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Sort contours by X-coordinate (left to right)
    sorted_contours = sorted(contours, key=lambda c: cv2.boundingRect(c)[0])

    # Calculate column boundaries
    column_boundaries = [cv2.boundingRect(c)[0] for c in sorted_contours]
    print("Detected column boundaries:", column_boundaries)

    # Crop each column
    for i in range(num_columns):
        x_start = column_boundaries[i]
        x_end = column_boundaries[i + 1] #if i < num_columns - 1 else image.width
        column_image = image.crop((x_start, 0, x_end, image.height))
        column_image.save(f"column{i + 1}.jpg")
        print(f"Saved column{i + 1}.jpg")

# Example usage: Detect column boundaries and crop the image into 5 columns
input_image_path = r"..\documents\Cut.jpg"
num_columns = 5
detect_column_boundaries(input_image_path, num_columns)
# Out:
# Detected column boundaries: [1, 4, 5, 5, 6, 6, 6, 6, 7, 15, 15, 17, 25, 48, 55, 56, 57, 57, 65, 268, 272, 277, 280, 286, 288, 316, 320, 326, 337, 342, 350, 351, 372, 481, 494, 528, 534, 661, 717, 729, 734, 751, 794, 816, 828, 868, 872, 890, 933, 1046, 1112, 1123, 1128, 1250, 1278, 1295, 1305, 1310, 1317, 1321, 1333, 1467, 1472, 1472, 1635, 1669, 1675, 1675, 1678, 1680, 1696, 1722, 1897, 1901, 1910, 2068, 2337, 2342]
# Saved column1.jpg
# Saved column2.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[175], line 39
#      37 input_image_path = r"..\documents\Cut.jpg"
#      38 num_columns = 5
# ---> 39 detect_column_boundaries(input_image_path, num_columns)
#
# Cell In[175], line 33, in detect_column_boundaries(image_path, num_columns)
#      31 x_end = column_boundaries[i + 1] #if i < num_columns - 1 else image.width
# ...

# %%
import cv2
from PIL import Image

# Load image, convert to grayscale, Otsu's threshold
image = cv2.imread(r"..\documents\Cut.jpg")
print('Image width is: ',Image.open(r"..\documents\ScanTest.jpg").width)    
result = image.copy()
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
#show the image
cv2.imwrite("binary_image.jpg", thresh)

# Detect horizontal lines
horizontal_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (800,1))
detect_horizontal = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, horizontal_kernel, iterations=2)
hor_cnts = cv2.findContours(detect_horizontal, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
hor_cnts = hor_cnts[0] if len(hor_cnts) == 2 else hor_cnts[1]
for c in hor_cnts:
    cv2.drawContours(result, [c], -1, (36,255,12), 2)
    #cv2.imwrite("result.jpg", result)
    
# Detect vertical lines
vertical_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1,25))
detect_vertical = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, vertical_kernel, iterations=2)
ver_cnts = cv2.findContours(detect_vertical, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
ver_cnts = ver_cnts[0] if len(ver_cnts) == 2 else ver_cnts[1]
for c in ver_cnts:
    cv2.drawContours(result, [c], -1, (36,255,12), 2)
    print('c:',[c])
    cv2.imwrite("result.jpg", result)
    
intersection_points = []
for h_countour in hor_cnts:
    for v_countour in ver_cnts:
        h_x,h_y,w,h = cv2.boundingRect(h_countour)
        v_x,v_y,w,h = cv2.boundingRect(v_countour)
        intersection_points.append((h_x,v_y))    

# Find the bounding box for the intersection points
x_min = min(point[0] for point in intersection_points)
y_min = min(point[1] for point in intersection_points)
x_max = max(point[0] for point in intersection_points)
y_max = max(point[1] for point in intersection_points)

# Crop the image to the bounding box
trimmed_image = image[y_min:y_max, x_min:x_max]

# Save the trimmed image
#cv2.imwrite("trimmed_image.jpg", trimmed_image)

# Print a success message
#print("ver_cnts :", ver_cnts)
print("Trimmed image saved as trimmed_image.jpg")
# Out:
# Image width is:  2480
# ver_cnts : (array([[[2362,   27]],
#
#        [[2362,  119]],
#
#        [[2366,  119]],
#
#        [[2366,   28]],
#
#        [[2365,   27]]], dtype=int32), array([[[1933,   26]],
#
#        [[1933,  119]],
#
#        [[1937,  119]],
#
#        [[1937,   27]],
#
#        [[1936,   26]],
#
#        [[1935,   26]],
#
#        [[1934,   27]]], dtype=int32), array([[[1499,   25]],
#
#        [[1498,   26]],
#
#        [[1494,   26]],
#
#        [[1494,  119]],
#
#        [[1499,  119]]], dtype=int32), array([[[1150,   25]],
#
#        [[1150,   93]],
#
#        [[1149,   94]],
#
#        [[1149,  119]],
#
#        [[1154,  119]],
#
#        [[1154,   25]]], dtype=int32), array([[[302,  24]],
#
#        [[302, 119]],
#
#        [[306, 119]],
#
#        [[306,  98]],
#
#        [[307,  97]],
#
#        [[307,  47]],
#
#        [[306,  46]],
#
#        [[306,  24]]], dtype=int32), array([[[ 29,  24]],
#
#        [[ 29, 119]],
#
#        [[ 33, 119]],
#
# ...

# %%
image = cv2.imread(r"..\documents\Cut.jpg")

result = image.copy()
print([c])
cv2.drawContours(result, [[2362,   27]], -1, (36,255,12), 2)
cv2.imwrite("result.jpg", result)
# Out:
# [array([[[ 29,  24]],
#
#        [[ 29, 119]],
#
#        [[ 33, 119]],
#
#        [[ 33, 115]],
#
#        [[ 34, 114]],
#
#        [[ 34,  34]],
#
#        [[ 33,  33]],
#
#        [[ 33,  24]]], dtype=int32)]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[54], line 5
#       3 result = image.copy()
#       4 print([c])
# ----> 5 cv2.drawContours(result, [[2362,   27]], -1, (36,255,12), 2)
#       6 cv2.imwrite("result.jpg", result)
#
# error: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'drawContours'
# > Overload resolution failed:
# >  - Can't parse 'contours'. Sequence item with index 0 has a wrong type
# >  - Can't parse 'contours'. Sequence item with index 0 has a wrong type
